# %%
import pandas as pd
import numpy as np
from evidently import Report, DataDefinition,Dataset
from evidently.presets import DataDriftPreset, DataSummaryPreset 

employment_train = pd.read_csv("train_employment.csv")
employment_test = pd.read_csv("test_employment.csv")





# leave only reasonable columns
employment_train = employment_train.drop(['Employee ID'], axis=1)
employment_test = employment_test.drop(['Employee ID'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from evidently import Report, DataDefinition,Dataset, ColumnMapping
#       4 from evidently.presets import DataDriftPreset, DataSummaryPreset
#       6 employment_train = pd.read_csv("train_employment.csv")
#
# ImportError: cannot import name 'ColumnMapping' from 'evidently' (c:\Users\User\Desktop\training\Evidently\.venv\lib\site-packages\evidently\__init__.py)

# %%
employment_train.head()
# Out:
#    Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0   31    Male                19   Education            5390
# 1   59  Female                 4       Media            5534
# 2   24  Female                10  Healthcare            8159
# 3   36  Female                 7   Education            3989
# 4   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
#   Overtime  ...  Number of Dependents Job Level Company Size  Company Tenure  \
# ...

# %%
drift_report = Report(metrics=[DataDriftPreset(), DataSummaryPreset()])
eval = drift_report.run(reference_data=eval_data_1, current_data=eval_data_2)
# some columns are not correctly classified


eval.save_html("employment_report.html")
